# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_parquet('Results_BERTopic/BERTopic_5_topics_15n_10com_1800cluster.parquet')
df1
# Out:
#                                                 Document  \
# 0                                tor shrinked contribute
# 1                   updated tor security guide crosspost
# 2      costcorotisseriechicken spreading fud let smas...
# 3                     hiring shadow simulation developer
# 4                does anyone know liberty market talking
# ...                                                  ...
# 32620                         market data purge policies
# 32621              censorship sign market something hide
# 32622                         vision behind local market
# 32623                           market listed deepdotweb
# 32624                                   vendor evaluated
#
#                                                Embedding  Topic  Probability  \
# 0      [0.0003665863, -0.10446195, 0.0029864428, 0.05...      1     1.000000
# 1      [-0.057483885, 0.026145194, 0.012629288, 0.042...      1     0.656116
# ...

# %%
df1.value_counts('Topic')
# Out:
# Topic
# 0    10308
# 1     8679
# 2     7076
# 3     4188
# 4     2374
# Name: count, dtype: int64

# %%
sns.histplot(df1, x='Topic', discrete=True);
# Out:
# <Axes: xlabel='Topic', ylabel='Count'>

# %%
plt.pie(df1.value_counts('Topic'), labels=df1.value_counts('Topic').index, autopct='%1.1f%%');
