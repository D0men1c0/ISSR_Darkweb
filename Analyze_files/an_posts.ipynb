# %% [markdown]
# # Library

# %%
import sys
sys.path.append('..')
import PreProcessingUtils as ppu
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
PATH = r"C:\Users\dommy\OneDrive\Documenti\GSoC - Final\GSoC\CSV\posts.csv"

# %%
df = pd.read_csv(PATH)
df
# Out:
#                 id  site_id  board_id   thread_id                 creator  \
# 0         36720469     1019       231   325823490             Spongebob18
# 1         24032363     1019        18   267995034         jayandsilentbob
# 2         24019342     1019        18   274398115                    fdsm
# 3        103044339     1019        18  1007020202  empiremarketlinkdotnet
# 4         26711942     1019       231    26711942               Subaru420
# ...            ...      ...       ...         ...                     ...
# 294591  1156421769     1019        80   454710885        BigBird1 Pelican
# 294592  1859088030     1019        10   161610195       HumboldtGrowersPR
# 294593   540386492     1019         2   540386492               QuickTrot
# 294594  1332512359     1019         2   512278408              drkoalaman
# 294595  1731387276     1019         2  1731387276               Eagerfear
#
#         creator_id  creator_n_posts  creator_reputation  \
# 0               97                0                   0
# 1            16521                0                   0
# 2             6451                0                   0
# 3            28892                0                   0
# 4             3501                0                   0
# ...            ...              ...                 ...
# 294591       12161                0                   0
# 294592         631                0                   0
# 294593        9722                0                   0
# 294594         806                0                   0
# 294595       11729                0                   0
#
#                                                   content quoted_post_ids  \
# 0                                               [removed]              {}
# 1                                              Sent to PM              {}
# 2             why in the actual fuck would you want fent?              {}
# 3                                               [removed]              {}
# 4       (Suggestion) Add the filter to hide inactive l...              {}
# ...                                                   ...             ...
# 294591  Trying to find out why we are banned right now...              {}
# 294592  So let me get this straight... You believe HG ...              {}
# 294593  **Vendor Review**\n\n* `Vendor` - *Pearl*\n\n*...              {}
# 294594  You are delusional as fuck.\n\nYou were banned...              {}
# 294595  Hello all,\nthis is my first time posting to t...              {}
#
#         ...                  created_on                  updated_on  \
# 0       ...         2019-04-23 18:16:00         2019-04-23 18:16:00
# 1       ...         2019-05-08 19:25:00         2019-05-08 19:25:00
# 2       ...         2019-05-03 23:19:00         2019-05-03 23:19:00
# 3       ...         2019-07-27 17:43:00         2019-07-27 17:43:00
# 4       ...  2019-08-06 16:43:33.188847  2019-08-06 16:43:33.188847
# ...     ...                         ...                         ...
# 294591  ...         2019-08-04 23:48:00         2019-08-04 23:48:00
# 294592  ...         2018-11-15 15:44:00         2018-11-15 15:44:00
# 294593  ...  2019-08-08 03:56:45.995964  2019-08-08 03:56:45.995964
# 294594  ...         2018-07-08 12:27:00         2018-07-08 12:27:00
# 294595  ...  2019-08-08 04:32:54.231525  2019-08-08 04:32:54.231525
#
#                      db_created_on               db_updated_on codes  \
# 0       2019-08-06 18:06:40.859515  2019-08-06 18:06:40.859515   NaN
# 1       2019-08-08 10:51:08.113685  2019-08-08 10:51:08.113685   NaN
# 2       2019-08-08 11:31:45.437428  2019-08-08 11:31:45.437428   NaN
# 3       2019-08-08 10:02:51.241563  2019-08-08 10:02:51.241563   NaN
# 4       2019-08-06 16:43:33.323708  2019-08-06 16:43:33.323708   NaN
# ...                            ...                         ...   ...
# 294591  2019-08-06 15:38:52.766424  2019-08-06 15:38:52.766424   NaN
# 294592  2019-08-07 16:54:59.138025  2019-08-07 16:54:59.138025   NaN
# 294593  2019-08-08 03:56:46.119398  2019-08-08 03:56:46.119398   NaN
# 294594  2019-08-08 04:05:51.125012  2019-08-08 04:05:51.125012   NaN
# 294595   2019-08-08 04:32:54.37903   2019-08-08 04:32:54.37903   NaN
#
#         creator_n_likes  creator_n_threads  creator_n_vouches  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 294591              NaN                NaN                NaN
# 294592              NaN                NaN                NaN
# 294593              NaN                NaN                NaN
# 294594              NaN                NaN                NaN
# 294595              NaN                NaN                NaN
#
#         creator_n_credits  attachment_url
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 294591                NaN             NaN
# 294592                NaN             NaN
# 294593                NaN             NaN
# 294594                NaN             NaN
# 294595                NaN             NaN
#
# [294596 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294596 entries, 0 to 294595
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  294596 non-null  int64
#  1   site_id             294596 non-null  int64
#  2   board_id            294596 non-null  int64
#  3   thread_id           294596 non-null  int64
#  4   creator             294596 non-null  object
#  5   creator_id          294596 non-null  int64
#  6   creator_n_posts     294596 non-null  int64
#  7   creator_reputation  294596 non-null  int64
#  8   content             294592 non-null  object
#  9   quoted_post_ids     294596 non-null  object
#  10  is_initial_post     294596 non-null  object
#  11  created_on          294596 non-null  object
#  12  updated_on          294596 non-null  object
#  13  db_created_on       294596 non-null  object
#  14  db_updated_on       294596 non-null  object
#  15  codes               0 non-null       float64
#  16  creator_n_likes     0 non-null       float64
#  17  creator_n_threads   0 non-null       float64
#  18  creator_n_vouches   0 non-null       float64
#  19  creator_n_credits   0 non-null       float64
#  20  attachment_url      0 non-null       float64
# dtypes: float64(6), int64(7), object(8)
# memory usage: 47.2+ MB

# %%
df.drop(columns=['site_id', 'codes', 'creator_n_likes', 'creator_n_threads', 'creator_n_vouches', 'creator_n_credits', 'attachment_url'], inplace=True)

# %%
df.describe()
# Out:
#                  id       board_id     thread_id     creator_id  \
# count  2.945960e+05  294596.000000  2.945960e+05  294596.000000
# mean   1.072838e+09      53.065266  1.075806e+09   13890.286175
# std    6.196729e+08      91.042142  6.155466e+08   13245.626335
# min    1.708000e+04       1.000000  3.372500e+04       1.000000
# 25%    5.356949e+08       5.000000  5.459303e+08    2389.000000
# 50%    1.073613e+09      18.000000  1.083728e+09    9099.000000
# 75%    1.608567e+09      42.000000  1.601679e+09   22859.000000
# max    2.147483e+09     446.000000  2.147418e+09   47532.000000
#
#        creator_n_posts  creator_reputation
# count         294596.0            294596.0
# mean               0.0                 0.0
# std                0.0                 0.0
# min                0.0                 0.0
# 25%                0.0                 0.0
# 50%                0.0                 0.0
# 75%                0.0                 0.0
# max                0.0                 0.0

# %%
df.describe(include='object')
# Out:
#           creator    content quoted_post_ids is_initial_post  \
# count      294596     294592          294596          294596
# unique      42683     270239               1               2
# top     [deleted]  [removed]              {}               f
# freq         4536      14155          294596          220498
#
#                  created_on           updated_on               db_created_on  \
# count                294596               294596                      294596
# unique               251949               251949                      294595
# top     2018-03-24 21:00:00  2018-03-24 21:00:00  2019-08-08 01:03:54.690351
# freq                     18                   18                           2
#
#                      db_updated_on
# count                       294596
# unique                      294595
# top     2019-08-08 01:03:54.690351
# freq                             2

# %%
df.nunique()
# Out:
# id                    294596
# board_id                 382
# thread_id              74098
# creator                42683
# creator_id             43629
# creator_n_posts            1
# creator_reputation         1
# content               270239
# quoted_post_ids            1
# is_initial_post            2
# created_on            251949
# updated_on            251949
# db_created_on         294595
# db_updated_on         294595
# dtype: int64

# %%
df['creator_n_posts'].value_counts()
# Out:
# creator_n_posts
# 0    294596
# Name: count, dtype: int64

# %%
df['creator_reputation'].value_counts()
# Out:
# creator_reputation
# 0    294596
# Name: count, dtype: int64

# %%
df['quoted_post_ids'].value_counts()
# Out:
# quoted_post_ids
# {}    294596
# Name: count, dtype: int64

# %%
df['is_initial_post'].value_counts()
# Out:
# is_initial_post
# f    220498
# t     74098
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                    0
# board_id              0
# thread_id             0
# creator               0
# creator_id            0
# creator_n_posts       0
# creator_reputation    0
# content               4
# quoted_post_ids       0
# is_initial_post       0
# created_on            0
# updated_on            0
# db_created_on         0
# db_updated_on         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[(df['db_created_on'] == df['db_updated_on'])][['db_created_on', 'db_updated_on', 'created_on']]
# Out:
#                      db_created_on               db_updated_on  \
# 0       2019-08-06 18:06:40.859515  2019-08-06 18:06:40.859515
# 1       2019-08-08 10:51:08.113685  2019-08-08 10:51:08.113685
# 2       2019-08-08 11:31:45.437428  2019-08-08 11:31:45.437428
# 3       2019-08-08 10:02:51.241563  2019-08-08 10:02:51.241563
# 4       2019-08-06 16:43:33.323708  2019-08-06 16:43:33.323708
# ...                            ...                         ...
# 294591  2019-08-06 15:38:52.766424  2019-08-06 15:38:52.766424
# 294592  2019-08-07 16:54:59.138025  2019-08-07 16:54:59.138025
# 294593  2019-08-08 03:56:46.119398  2019-08-08 03:56:46.119398
# 294594  2019-08-08 04:05:51.125012  2019-08-08 04:05:51.125012
# 294595   2019-08-08 04:32:54.37903   2019-08-08 04:32:54.37903
#
#                         created_on
# 0              2019-04-23 18:16:00
# 1              2019-05-08 19:25:00
# 2              2019-05-03 23:19:00
# 3              2019-07-27 17:43:00
# 4       2019-08-06 16:43:33.188847
# ...                            ...
# 294591         2019-08-04 23:48:00
# 294592         2018-11-15 15:44:00
# 294593  2019-08-08 03:56:45.995964
# 294594         2018-07-08 12:27:00
# 294595  2019-08-08 04:32:54.231525
#
# [294596 rows x 3 columns]

# %%
df.drop(columns=['is_initial_post', 'quoted_post_ids', 'creator_reputation', 'creator_n_posts', 'db_created_on', 'db_updated_on'], inplace=True)

# %%
df.head()
# Out:
#           id  board_id   thread_id                 creator  creator_id  \
# 0   36720469       231   325823490             Spongebob18          97
# 1   24032363        18   267995034         jayandsilentbob       16521
# 2   24019342        18   274398115                    fdsm        6451
# 3  103044339        18  1007020202  empiremarketlinkdotnet       28892
# 4   26711942       231    26711942               Subaru420        3501
#
#                                              content  \
# 0                                          [removed]
# 1                                         Sent to PM
# 2        why in the actual fuck would you want fent?
# 3                                          [removed]
# 4  (Suggestion) Add the filter to hide inactive l...
#
#                    created_on                  updated_on
# 0         2019-04-23 18:16:00         2019-04-23 18:16:00
# 1         2019-05-08 19:25:00         2019-05-08 19:25:00
# 2         2019-05-03 23:19:00         2019-05-03 23:19:00
# 3         2019-07-27 17:43:00         2019-07-27 17:43:00
# 4  2019-08-06 16:43:33.188847  2019-08-06 16:43:33.188847

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294596 entries, 0 to 294595
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          294596 non-null  int64
#  1   board_id    294596 non-null  int64
#  2   thread_id   294596 non-null  int64
#  3   creator     294596 non-null  object
#  4   creator_id  294596 non-null  int64
#  5   content     294592 non-null  object
#  6   created_on  294596 non-null  object
#  7   updated_on  294596 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 18.0+ MB

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Created_on & updated_on

# %%
df.shape
# Out:
# (294596, 8)

# %%
df[(df['created_on'] == df['updated_on'])][['created_on', 'updated_on']]
# Out:
#                         created_on                  updated_on
# 0              2019-04-23 18:16:00         2019-04-23 18:16:00
# 1              2019-05-08 19:25:00         2019-05-08 19:25:00
# 2              2019-05-03 23:19:00         2019-05-03 23:19:00
# 3              2019-07-27 17:43:00         2019-07-27 17:43:00
# 4       2019-08-06 16:43:33.188847  2019-08-06 16:43:33.188847
# ...                            ...                         ...
# 294591         2019-08-04 23:48:00         2019-08-04 23:48:00
# 294592         2018-11-15 15:44:00         2018-11-15 15:44:00
# 294593  2019-08-08 03:56:45.995964  2019-08-08 03:56:45.995964
# 294594         2018-07-08 12:27:00         2018-07-08 12:27:00
# 294595  2019-08-08 04:32:54.231525  2019-08-08 04:32:54.231525
#
# [294596 rows x 2 columns]

# %%
df.drop(columns=['updated_on'], inplace=True)

# %%
df['created_on'].value_counts(dropna=False)
# Out:
# created_on
# 2018-03-24 21:00:00           18
# 2019-05-08 18:56:00           10
# 2019-05-06 23:51:00            9
# 2019-05-06 21:33:00            9
# 2019-05-08 18:06:00            8
#                               ..
# 2019-08-06 10:28:49.413603     1
# 2019-08-08 01:21:40.805566     1
# 2019-08-08 13:12:31.88519      1
# 2019-08-07 18:17:54.555916     1
# 2019-08-08 04:32:54.231525     1
# Name: count, Length: 251949, dtype: int64

# %%
df['created_on'] = df['created_on'].apply(ppu.convert_millisecond_date)
df['created_on'] = df['created_on'].dt.strftime('%Y-%m-%d')

# %%
df['created_on'].value_counts(dropna=False)
# Out:
# created_on
# 2019-08-08    26858
# 2019-08-07    14427
# 2019-08-06    13848
# 2019-12-31     3682
# 2020-01-08     3213
#               ...
# 2019-11-10       10
# 2018-05-28        9
# 2019-06-26        2
# 2019-05-19        1
# 2019-11-25        1
# Name: count, Length: 629, dtype: int64
