# %%
import pandas as pd
pd.read_csv('intent_crime.csv')
# Out:
#                intent  Unnamed: 1
# 0           abduction         NaN
# 1               arson         NaN
# 2             bombing         NaN
# 3            burglary         NaN
# 4         child abuse         NaN
# 5          corruption         NaN
# 6          cybercrime         NaN
# 7               drugs         NaN
# 8           espionage         NaN
# 9               fraud         NaN
# 10           genocide         NaN
# 11  government attack         NaN
# 12                gun         NaN
# 13     identity theft         NaN
# 14         kidnapping         NaN
# 15       manipulation         NaN
# 16             murder         NaN
# 17  organ trafficking         NaN
# 18         pedophilia         NaN
# 19               rape         NaN
# 20          terrorism         NaN
# 21        trafficking         NaN
